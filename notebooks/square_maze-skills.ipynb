# %% [markdown]
# ## Imports

# %%
import os
import sys
import matplotlib.pyplot as plt

sys.path.append("..")
os.environ["ROOT_DIR"] = ".."  # this allows to use relative paths in config files
from result_inspection.toy_maze import *
from result_inspection.plot_helpers import *

# %% [markdown]
# ## Plot config

# %%
plot_kwargs = dict(stat_list=['cumulative_rew'], labels=['Reward'], figsize=(6, 4), titlesize=14)
skill_kwargs = dict(figsize=(5,5), reset_dict=dict(state=torch.tensor([0., -0.5])))

# %% [markdown]
# ## Baseline: Forward MI

# %%
# name = "temp/5_tempposneg_seed2"
# name = 'cic'
# name = '.'

# algo = "forward_mi"
# algo = "reverse_mi"
# algo = "cic_mi"
algo = "contrastive_mi"
env = "square_maze"
# env = "square_tree"
# env = "tree_maze"


exp, cmap = load_exp_data(f"{env}/{algo}", notebook_mode=False)
# plot_stats_by_name(exp, **plot_kwargs)
# ax = plot_all_skills(exp, cmap, title="Reverse_MI", notebook_mode=False,  **skill_kwargs)
ax = plot_all_skills(exp, cmap, notebook_mode=False,  **skill_kwargs)
# env = "tree_maze"
plt.savefig("../MI-result/"+algo+"_"+env+'.png', dpi=300)
# Out:
# ...
# Trajectories: 100%|██████████| 20/20 [00:10<00:00,  1.84it/s]

# %% [markdown]
# ## Baseline: Reverse MI

# %%
exp, cmap = load_exp_data("square_maze/forward_mi")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, **skill_kwargs)
plt.savefig('DADS.pdf')

# %% [markdown]
# ## EDL+SR: oracle

# %%
exp, cmap = load_exp_data("square_maze/edl_sr_oracle")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR (oracle)", **skill_kwargs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_31825/2469199166.py in <module>
# ----> 1 exp, cmap = load_exp_data("square_maze/edl_sr_oracle")
#       2 plot_stats_by_name(exp, **plot_kwargs)
#       3 ax = plot_all_skills(exp, cmap, title="EDL+SR (oracle)", **skill_kwargs)
#
# ~/Desktop/edl/result_inspection/toy_maze.py in load_exp_data(exp_name, notebook_mode)
#      30
#      31 def load_exp_data(exp_name, notebook_mode=True):
# ---> 32     exp = Experiment(exp_name, notebook_mode=notebook_mode)
#      33     agent = exp.learner.agent
#      34     if agent.skill_n <= 10:
#
# ~/Desktop/edl/result_inspection/experiment.py in __init__(self, exp_name, ax_height, load_stats, load_evals, load_model, notebook_mode)
#     179         # Load the agent
#     180         if self._load_model:
# ...

# %% [markdown]
# ## EDL+SR: SMM exploration

# %%
exp, cmap = load_exp_data("square_maze/edl_sr_smm")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR (SMM exploration)", **skill_kwargs)

# %% [markdown]
# ## EDL: oracle
#
# Without Sibling Rivalry, agents often get stuck in deceptive local optima

# %%
exp, cmap = load_exp_data("square_maze/edl_oracle")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL (oracle)", **skill_kwargs)
